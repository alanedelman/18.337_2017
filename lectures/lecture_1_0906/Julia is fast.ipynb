# %% [markdown]
# # Julia is fast
#
# Very often, benchmarks are used to compare languages.  These benchmarks can lead to long discussions, first as to exactly what is being benchmarked and secondly what explains the differences.  These simple questions can sometimes get more complicated than you at first might imagine.
#
# The purpose of this notebook is for you to see a simple benchmark for yourself.  One can read the notebook and see what happened on the author's Macbook Pro with a 4-core Intel Core I7, or run the notebook yourself.
#
# (This material began life as a wonderful lecture by Steven Johnson at MIT: https://github.com/stevengj/18S096-iap17/blob/master/lecture1/Boxes-and-registers.ipynb.)

# %% [markdown]
# # `sum`: An easy enough function to understand

# %% [markdown]
# Consider the  **sum** function `sum(a)`, which computes
# $$
# \mathrm{sum}(a) = \sum_{i=1}^n a_i,
# $$
# where $n$ is the length of `a`.

# %%
a = rand(10^7) # 1D vector of random numbers, uniform on [0,1)
# Out:
# 10000000-element Array{Float64,1}:
#  0.213666
#  0.204802
#  0.277555
#  0.872333
#  0.107292
#  0.0105418
#  0.598601
#  0.633041
#  0.0687061
#  0.12222
#  0.0938273
#  0.0804258
#  0.0347976
#  ⋮
#  0.968152
#  0.652859
#  0.410707
#  0.870957
#  0.155245
#  0.865663
#  0.792246
#  0.803008
#  0.064752
#  0.933898
#  0.26443
#  0.356144

# %%
sum(a)
# Out:
# 5.000778733094821e6

# %%
@time sum(a)

@time sum(a)

@time sum(a)
# Out:
#   0.040238 seconds (9.81 k allocations: 557.658 KiB)
#   0.005903 seconds (5 allocations: 176 bytes)
#   0.005416 seconds (5 allocations: 176 bytes)
# 4.999018624196265e6

# %% [markdown]
# The expected result is 0.5 * 10^7, since the mean of each entry is 0.5

# %% [markdown]
# # Benchmarking a few ways in a few languages

# %% [markdown]
# Julia has a `BenchmarkTools.jl` package for easy and accurate benchmarking:

# %%
#Pkg.add("BenchmarkTools")

# %%
using BenchmarkTools

# %% [markdown]
# #  1. The C language
#
# C is often considered the gold standard: difficult on the human, nice for the machine. Getting within a factor of 2 of C is often satisfying. Nonetheless, even within C, there are many kinds of optimizations possible that a naive C writer may or may not get the advantage of.
#
# The current author does not speak C, so he does not read the cell below, but is happy to know that you can put C code in a Julia session, compile it, and run it. Note that the `"""` wrap a multi-line string.

# %%
C_code = """
#include <stddef.h>
double c_sum(size_t n, double *X) {
    double s = 0.0;
    for (size_t i = 0; i < n; ++i) {
        s += X[i];
    }
    return s;
}
"""

const Clib = tempname()   # make a temporary file


# compile to a shared library by piping C_code to gcc
# (works only if you have gcc installed):

open(`gcc -fPIC -O3 -msse3 -xc -shared -o $(Clib * "." * Libdl.dlext) -`, "w") do f
    print(f, C_code) 
end

# define a Julia function that calls the C function:
c_sum(X::Array{Float64}) = ccall(("c_sum", Clib), Float64, (Csize_t, Ptr{Float64}), length(X), X)
# Out:
# c_sum (generic function with 1 method)

# %%
c_sum(a)
# Out:
# 5.000778733094707e6

# %%
c_sum(a) ≈ sum(a) # type \approx and then <TAB> to get the ≈ symbolb
# Out:
# true

# %%
c_sum(a) - sum(a)
# Out:
# -1.1362135410308838e-7

# %%
≈  # alias for the `isapprox` function

# %%
?isapprox
# Out:
# search: isapprox
# ```
# isapprox(x, y; rtol::Real=sqrt(eps), atol::Real=0, nans::Bool=false, norm::Function)
# ```
#
# Inexact equality comparison: `true` if `norm(x-y) <= atol + rtol*max(norm(x), norm(y))`. The default `atol` is zero and the default `rtol` depends on the types of `x` and `y`. The keyword argument `nans` determines whether or not NaN values are considered equal (defaults to false).
#
# For real or complex floating-point values, `rtol` defaults to `sqrt(eps(typeof(real(x-y))))`. This corresponds to requiring equality of about half of the significand digits. For other types, `rtol` defaults to zero.
#
# `x` and `y` may also be arrays of numbers, in which case `norm` defaults to `vecnorm` but may be changed by passing a `norm::Function` keyword argument. (For numbers, `norm` is the same thing as `abs`.) When `x` and `y` are arrays, if `norm(x-y)` is not finite (i.e. `±Inf` or `NaN`), the comparison falls back to checking whether all elements of `x` and `y` are approximately equal component-wise.
#
# The binary operator `≈` is equivalent to `isapprox` with the default arguments, and `x ≉ y` is equivalent to `!isapprox(x,y)`.
#
# ```jldoctest
# julia> 0.1 ≈ (0.1 - 1e-10)
# true
#
# julia> isapprox(10, 11; atol = 2)
# true
#
# julia> isapprox([10.0^9, 1.0], [10.0^9, 2.0])
# true
# ```

# %% [markdown]
# We can now benchmark the C code directly from Julia:

# %%
c_bench = @benchmark c_sum($a)
# Out:
# BenchmarkTools.Trial:
#   memory estimate:  0 bytes
#   allocs estimate:  0
#   --------------
#   minimum time:     8.274 ms (0.00% GC)
#   median time:      8.840 ms (0.00% GC)
#   mean time:        9.482 ms (0.00% GC)
#   maximum time:     13.266 ms (0.00% GC)
#   --------------
#   samples:          527
#   evals/sample:     1

# %%
println("C: Fastest time was $(minimum(c_bench.times) / 1e6) msec")
# Out:
# C: Fastest time was 8.273756 msec

# %%
d = Dict()  # a "dictionary", i.e. an associative array
d["C"] = minimum(c_bench.times) / 1e6  # in milliseconds
d
# Out:
# Dict{Any,Any} with 1 entry:
#   "C" => 8.27376

# %%
using Plots
gr()
# Out:
# Plots.GRBackend()

# %%
t = c_bench.times / 1e6 # times in milliseconds
m, σ = minimum(t), std(t)

histogram(t, bins=500,
    xlim=(m - 0.01, m + σ),
    xlabel="milliseconds", ylabel="count", label="")
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="600" height="400" viewBox="0 0 600 400">
# <defs>
#   <clipPath id="clip00">
#     <rect x="0" y="0" width="600" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip00)" points="
# 0,400 600,400 600,0 0,0
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip01">
#     <rect x="120" y="0" width="421" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip00)" points="
# 44.6753,360.065 580.315,360.065 580.315,11.811 44.6753,11.811
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip02">
#     <rect x="44" y="11" width="537" height="349"/>
#   </clipPath>
# </defs>
# <polyline clip-path="url(#clip02)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   146.158,354.842 146.158,17.0348
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   360.94,354.842 360.94,17.0348
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   575.723,354.842 575.723,17.0348
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   52.7099,360.065 572.28,360.065
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   52.7099,302.023 572.28,302.023
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   52.7099,243.981 572.28,243.981
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   52.7099,185.938 572.28,185.938
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   52.7099,127.896 572.28,127.896
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   52.7099,69.8534 572.28,69.8534
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   52.7099,11.811 572.28,11.811
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   44.6753,360.065 580.315,360.065
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   146.158,360.065 146.158,354.842
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   360.94,360.065 360.94,354.842
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   575.723,360.065 575.723,354.842
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   44.6753,360.065 44.6753,11.811
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   44.6753,360.065 52.7099,360.065
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   44.6753,302.023 52.7099,302.023
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   44.6753,243.981 52.7099,243.981
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   44.6753,185.938 52.7099,185.938
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   44.6753,127.896 52.7099,127.896
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   44.6753,69.8534 52.7099,69.8534
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   44.6753,11.811 52.7099,11.811
#   "/>
# <g clip-path="url(#clip00)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 146.158, 373.865)" x="146.158" y="373.865">8.5</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 360.94, 373.865)" x="360.94" y="373.865">9.0</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 575.723, 373.865)" x="575.723" y="373.865">9.5</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 38.6753, 364.565)" x="38.6753" y="364.565">0</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 38.6753, 306.523)" x="38.6753" y="306.523">2</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 38.6753, 248.481)" x="38.6753" y="248.481">4</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 38.6753, 190.438)" x="38.6753" y="190.438">6</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 38.6753, 132.396)" x="38.6753" y="132.396">8</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 38.6753, 74.3534)" x="38.6753" y="74.3534">10</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 38.6753, 16.311)" x="38.6753" y="16.311">12</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:16; text-anchor:middle;" transform="rotate(0, 312.495, 397.6)" x="312.495" y="397.6">milliseconds</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:16; text-anchor:middle;" transform="rotate(-90, 14.4, 185.938)" x="14.4" y="185.938">count</text>
# </g>
# <polygon clip-path="url(#clip02)" points="
# 47.3575,331.044 47.3575,360.065 51.6532,360.065 51.6532,331.044 47.3575,331.044 47.3575,331.044
#   " fill="#009af9" fill-opacity="1"/>
# <polyline clip-path="url(#clip02)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   47.3575,331.044 47.3575,360.065 51.6532,360.065 51.6532,331.044 47.3575,331.044
#   "/>
# <polygon clip-path="url(#clip02)" points="
# 51.6532,360.065 51.6532,360.065 55.9488,360.065 55.9488,360.065 51.6532,360.065 51.6532,360.065
#   " fill="#009af9" fill-opacity="1"/>
# <polyline clip-path="url(#clip02)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   51.6532,360.065 51.6532,360.065 55.9488,360.065 51.6532,360.065
#   "/>
# <polygon clip-path="url(#clip02)" points="
# 55.9488,360.065 55.9488,360.065 60.2445,360.065 60.2445,360.065 55.9488,360.065 55.9488,360.065
#   " fill="#009af9" fill-opacity="1"/>
# <polyline clip-path="url(#clip02)" style="stroke:#000000; stroke-width:1; stroke-opacit

# %% [markdown]
# # 2. Python's built in `sum`

# %% [markdown]
# The `PyCall` package provides a Julia interface to Python:

# %%
#Pkg.add("PyCall")

# %%
using PyCall

# %%
# Call a low-level PyCall function to get a Python list, because
# by default PyCall will convert to a NumPy array instead (we benchmark NumPy below):

apy_list = PyCall.array2py(a, 1, 1)

# get the Python built-in "sum" function:
pysum = pybuiltin("sum")
# Out:
# PyObject <built-in function sum>

# %%
pysum(a)
# Out:
# 5.000778733094707e6

# %%
pysum(a) ≈ sum(a)
# Out:
# true

# %%
py_list_bench = @benchmark $pysum($apy_list)
# Out:
# BenchmarkTools.Trial:
#   memory estimate:  512 bytes
#   allocs estimate:  17
#   --------------
#   minimum time:     74.335 ms (0.00% GC)
#   median time:      84.946 ms (0.00% GC)
#   mean time:        84.084 ms (0.00% GC)
#   maximum time:     92.649 ms (0.00% GC)
#   --------------
#   samples:          60
#   evals/sample:     1

# %%
d["Python built-in"] = minimum(py_list_bench.times) / 1e6
d
# Out:
# Dict{Any,Any} with 2 entries:
#   "C"               => 8.27376
#   "Python built-in" => 74.3354

# %% [markdown]
# # 3. Python: `numpy`
#
# ## Takes advantage of hardware "SIMD", but only works when it works.
#
# `numpy` is an optimized C library, callable from Python.
# It may be installed within Julia as follows:

# %%
using Conda 
#Conda.add("numpy")

# %%
numpy_sum = pyimport("numpy")["sum"]
apy_numpy = PyObject(a) # converts to a numpy array by default

py_numpy_bench = @benchmark $numpy_sum($apy_numpy)
# Out:
# BenchmarkTools.Trial:
#   memory estimate:  720 bytes
#   allocs estimate:  22
#   --------------
#   minimum time:     3.975 ms (0.00% GC)
#   median time:      4.229 ms (0.00% GC)
#   mean time:        4.457 ms (0.00% GC)
#   maximum time:     8.445 ms (0.00% GC)
#   --------------
#   samples:          1120
#   evals/sample:     1

# %%
numpy_sum(apy_list) # python thing
# Out:
# 5.000778733094821e6

# %%
numpy_sum(apy_list) ≈ sum(a)
# Out:
# true

# %%
d["Python numpy"] = minimum(py_numpy_bench.times) / 1e6
d
# Out:
# Dict{Any,Any} with 3 entries:
#   "C"               => 8.27376
#   "Python numpy"    => 3.9749
#   "Python built-in" => 74.3354

# %% [markdown]
# # 4. Python, hand-written

# %%
py"""
def py_sum(a):
    s = 0.0
    for x in a:
        s = s + x
    return s
"""

sum_py = py"py_sum"
# Out:
# PyObject <function py_sum at 0x1422c6cf8>

# %%
py_hand = @benchmark $sum_py($apy_list)
# Out:
# BenchmarkTools.Trial:
#   memory estimate:  512 bytes
#   allocs estimate:  17
#   --------------
#   minimum time:     457.811 ms (0.00% GC)
#   median time:      471.950 ms (0.00% GC)
#   mean time:        472.880 ms (0.00% GC)
#   maximum time:     497.459 ms (0.00% GC)
#   --------------
#   samples:          11
#   evals/sample:     1

# %%
@which sum([1.5])
# Out:
# sum(a) in Base at reduce.jl:359

# %%
ccall(:sleep, Void, (Cint,), 3)

# %%
Cint, Csize_t
# Out:
# (Int32, UInt64)

# %%
sum_py(apy_list)
# Out:
# 5.000778733094707e6

# %%
sum_py(apy_list) ≈ sum(a)
# Out:
# true

# %%
d["Python hand-written"] = minimum(py_hand.times) / 1e6
d
# Out:
# Dict{Any,Any} with 4 entries:
#   "C"                   => 8.27376
#   "Python numpy"        => 3.9749
#   "Python hand-written" => 457.811
#   "Python built-in"     => 74.3354

# %% [markdown]
# # 5. Julia (built-in)
#
# ## Written directly in Julia, not in C!

# %%
@which sum(a)
# Out:
# sum(a) in Base at reduce.jl:359

# %%
j_bench = @benchmark sum($a)
# Out:
# BenchmarkTools.Trial:
#   memory estimate:  0 bytes
#   allocs estimate:  0
#   --------------
#   minimum time:     3.799 ms (0.00% GC)
#   median time:      4.448 ms (0.00% GC)
#   mean time:        4.600 ms (0.00% GC)
#   maximum time:     7.278 ms (0.00% GC)
#   --------------
#   samples:          1085
#   evals/sample:     1

# %%
d["Julia built-in"] = minimum(j_bench.times) / 1e6
d
# Out:
# Dict{Any,Any} with 5 entries:
#   "C"                   => 8.27376
#   "Python numpy"        => 3.9749
#   "Python hand-written" => 457.811
#   "Python built-in"     => 74.3354
#   "Julia built-in"      => 3.79852

# %% [markdown]
# # 6. Julia (hand-written)

# %%
function mysum(A)   
    s = 0.0  # s = zero(eltype(A))
    for a in A
        s += a
    end
    s
end
# Out:
# mysum (generic function with 1 method)

# %%
j_bench_hand = @benchmark mysum($a)
# Out:
# BenchmarkTools.Trial:
#   memory estimate:  0 bytes
#   allocs estimate:  0
#   --------------
#   minimum time:     8.558 ms (0.00% GC)
#   median time:      9.237 ms (0.00% GC)
#   mean time:        9.842 ms (0.00% GC)
#   maximum time:     13.489 ms (0.00% GC)
#   --------------
#   samples:          508
#   evals/sample:     1

# %%
d["Julia hand-written"] = minimum(j_bench_hand.times) / 1e6
d
# Out:
# Dict{Any,Any} with 6 entries:
#   "C"                   => 8.27376
#   "Python numpy"        => 3.9749
#   "Julia hand-written"  => 8.55803
#   "Python hand-written" => 457.811
#   "Python built-in"     => 74.3354
#   "Julia built-in"      => 3.79852

# %% [markdown]
# # Summary

# %%
for (key, value) in sort(collect(d))
    println(rpad(key, 20, "."), lpad(round(value, 1), 8, "."))
end
# Out:
# C........................8.3
# Julia built-in...........3.8
# Julia hand-written.......8.6
# Python built-in.........74.3
# Python hand-written....457.8
# Python numpy.............4.0

# %%
for (key, value) in sort(collect(d), by=x->x[2])
    println(rpad(key, 20, "."), lpad(round(value, 2), 10, "."))
end
# Out:
# Julia built-in.............3.8
# Python numpy..............3.97
# C.........................8.27
# Julia hand-written........8.56
# Python built-in..........74.34
# Python hand-written.....457.81
