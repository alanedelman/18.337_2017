# %% [markdown]
# # Designing Markov chains

# %% [markdown]
# How can we design a Markov chain such that it converges to a given distribution $\pi(s)$ over states $s$?
# The idea is to design the chain such that it has a **stationary distribution** to which it converges after a long time, and such that that stationary distribution is equal to $\pi$.

# %% [markdown]
# To do so, we need to find (design) suitable transition probabilities $p(s \to t)$ of jumping from a state $s$ to a state $t$.
#
# The simplest design method is to impose the **detailed balance** criterion,
#
# $$\pi(s) p(s \to t) = \pi(t) p(t \to s) \quad \forall s, t,$$
#
# which says that the flow of probability between any two states is equal, and hence that there is an equilibrium between any two states.
# [This is not a necessary condition: there are MCMC methods that impose only the weaker "balance" condition that the *total* flow into and out of a given state should be equal.]
#
# This then imposes a condition on the ratio
# $$\frac{p(s \to t)}{p(t \to s)} = \frac{\pi(t)}{\pi(s)}.$$
#
# Note that the normalization constant disappears in this ratio of values of $\pi$, so that we can design a chain for a distribution whose normalization constant we don't know.

# %% [markdown]
# There are many ways to solve this underdetermined set of equations. The Metropolis solution is the following.
#
# We split up $p(s \to t)$ into $g(s \to t) \cdot \alpha(s \to t)$, where $g(s \to t)$ is the probability of proposing (generating) the state $t$ from the state $s$, and $\alpha(s \to t)$ is the probability of accepting the move.
#
# If $g$ is symmetric, such that $g(s \to t) = g(t \to s)$ for all $s, t$, then we have
#
# $$\frac{\alpha(s \to t)}{\alpha(t \to s)} = \frac{\pi(t)}{\pi(s)}.$$

# %% [markdown]
# We attempt to maximise the acceptance ratio $\alpha(s \to t)$ by putting it equal to $1$ when possible. The solution is
#
# $$\alpha(s \to t) = \max \left[ 1, \frac{\pi(s)}{\pi(t)} \right].$$
#
# Note that this choice implies that the probability of going "downhill" (to a less likely state) is 1.

# %% [markdown]
# See also [this Wikipedia article](https://en.wikipedia.org/wiki/Metropolis%E2%80%93Hastings_algorithm) and e.g. the book by Newman & Barkema, Monte Carlo Methods in Statistical Physics.

# %% [markdown]
# ## Code for simplest Metropolis MCMC

# %%
doc"""Generate a distribution looking like the (unnormalised) function f using MCMC"""
function MCMC(f, N=100000)

    data = Float64[]
    
    x = 0.0

    for i in 1:N
        x_new = x + 0.1*(rand() - 0.5)  # generate new state locally

        ratio = f(x_new) / f(x)

        if rand() < ratio
            x = x_new
        end

        push!(data, x)
    end
    
    return data
end
# Out:
# MCMC

# %%
using Plots
gr()
# Out:
# Plots.GRBackend()

# %%
data = MCMC(x->exp(-x^2), 10^7)
histogram(data, normed=true, bins=100)
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="600" height="400" viewBox="0 0 600 400">
# <defs>
#   <clipPath id="clip00">
#     <rect x="0" y="0" width="600" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip00)" points="
# 0,400 600,400 600,0 0,0
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip01">
#     <rect x="120" y="0" width="421" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip00)" points="
# 39.3701,376.378 592.126,376.378 592.126,7.87402 39.3701,7.87402
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip02">
#     <rect x="39" y="7" width="553" height="369"/>
#   </clipPath>
# </defs>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   169.085,370.85 169.085,13.4016
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   332.044,370.85 332.044,13.4016
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   495.003,370.85 495.003,13.4016
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   47.6614,376.378 583.835,376.378
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   47.6614,311.15 583.835,311.15
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   47.6614,245.923 583.835,245.923
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   47.6614,180.695 583.835,180.695
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   47.6614,115.467 583.835,115.467
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   47.6614,50.2394 583.835,50.2394
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   39.3701,376.378 592.126,376.378
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   169.085,376.378 169.085,370.85
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   332.044,376.378 332.044,370.85
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   495.003,376.378 495.003,370.85
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   39.3701,376.378 39.3701,7.87402
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   39.3701,376.378 47.6614,376.378
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   39.3701,311.15 47.6614,311.15
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   39.3701,245.923 47.6614,245.923
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   39.3701,180.695 47.6614,180.695
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   39.3701,115.467 47.6614,115.467
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   39.3701,50.2394 47.6614,50.2394
#   "/>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 169.085, 390.178)" x="169.085" y="390.178">-2</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 332.044, 390.178)" x="332.044" y="390.178">0</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 495.003, 390.178)" x="495.003" y="390.178">2</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 33.3701, 380.878)" x="33.3701" y="380.878">0.0</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 33.3701, 315.65)" x="33.3701" y="315.65">0.1</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 33.3701, 250.423)" x="33.3701" y="250.423">0.2</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 33.3701, 185.195)" x="33.3701" y="185.195">0.3</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 33.3701, 119.967)" x="33.3701" y="119.967">0.4</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 33.3701, 54.7394)" x="33.3701" y="54.7394">0.5</text>
# </g>
# <polygon clip-path="url(#clip02)" points="
# 55.0141,376.374 55.0141,376.378 63.162,376.378 63.162,376.374 55.0141,376.374 55.0141,376.374
#   " fill="#0099ff" fill-opacity="1"/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   55.0141,376.374 55.0141,376.378 63.162,376.378 63.162,376.374 55.0141,376.374
#   "/>
# <polygon clip-path="url(#clip02)" points="
# 63.162,376.345 63.162,376.378 71.31,376.378 71.31,376.345 63.162,376.345 63.162,376.345
#   " fill="#0099ff" fill-opacity="1"/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   63